# %%
#Knjižnice
load("funkcije.sage")

# %% [markdown]
# Za grafe z devetimi vozlišči preštejemo, za koliko grafov velja alpha_od(G)=1. Za grafe do šest vozlišč pa vse grafe tudi narišemo.

# %%
counts, results = count_and_draw_alpha_od_1(n_max=9, only_connected=False)
# Out:
# n = 1: število grafov z alpha_od(G) = 1 -> 1
# Graphics Array of size 1 x 1
# ----------------------------------------
# n = 2: število grafov z alpha_od(G) = 1 -> 1
# Graphics Array of size 1 x 1
# ----------------------------------------
# n = 3: število grafov z alpha_od(G) = 1 -> 2
# Graphics Array of size 1 x 2
# ----------------------------------------
# n = 4: število grafov z alpha_od(G) = 1 -> 4
# Graphics Array of size 1 x 4
# ----------------------------------------
# n = 5: število grafov z alpha_od(G) = 1 -> 11
# Graphics Array of size 3 x 5
# ----------------------------------------
# n = 6: število grafov z alpha_od(G) = 1 -> 43
# Graphics Array of size 9 x 5
# ----------------------------------------
# n = 7: število grafov z alpha_od(G) = 1 -> 266
# ----------------------------------------
# n = 8: število grafov z alpha_od(G) = 1 -> 3042
# ----------------------------------------
# n = 9: število grafov z alpha_od(G) = 1 -> 69645
# ...
